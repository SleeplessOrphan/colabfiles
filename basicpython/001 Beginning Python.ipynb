# %% [markdown]
# # Handling Basic Input and Output in Google Colab
#
# ## Objective
# In this lesson, we'll learn the essentials of handling basic input and output in Python, using Google Colab as our environment. We'll explore different functions and their usage in Python programming.
#
# ## Skills Covered
# - Using Google Colab
# - Understanding basic input/output functions in Python
# - Error handling with `try` and `except`
#
# ## Prerequisites
# Before starting, you should have:
# - A fundamental understanding of Python syntax
# - A Google Colab account
# - Basic familiarity with Jupyter notebook interface
#
# ## Materials Required
# - A computer with internet access
# - Google Colab account
#
# ---
#
# ## Lesson Steps

# %% [markdown]
# ### Step 1: Understanding `input()`
# The `input()` function is used to get user input. In Google Colab, add the following lines to a new cell:
#
# ```python
# user_input = input("Enter something: ")
# print("You entered:", user_input)
# ```
#
# Run the cell and enter a value when prompted.

# %%
# Enter your code here

# %% [markdown]
# ### Step 2: Using `print()` for Output
# The `print()` function displays the output. Try printing different types of data:
#
# ```python
# print("Hello, World!")
# print(123)
# print(3.14)
# ```

# %%
# Enter your code here

# %% [markdown]
# ### Step 3: Converting Data Types
# Conversion functions like `int()`, `str()`, and `float()` change the data type of a value. Try these examples:
#
# ```python
# # Converting string to integer
# number = int("10")
# print(number)
#
# # Converting integer to string
# text = str(123)
# print(text)
#
# # Converting string to float
# decimal = float("2.5")
# print(decimal)
# ```

# %%
# Enter your code here

# %% [markdown]
# ### Step 4: Implementing `try` and `except`
# These keywords are used for handling exceptions. Here's how to use them:
#
# ```python
# try:
#     # Try converting a non-numeric string to an integer
#     num = int("hello")
# except ValueError:
#     print("That was not a number!")
# ```

# %%
# Enter your code here

# %% [markdown]
# ## Independent Practice Tasks
#
# ### Task 1: User Input and Response
# Write a program that asks the user for their name and age, then prints a message saying how many years it will be until they turn 100. Use `input()` to get user input and `print()` for output.

# %%
# Enter your code here

# %% [markdown]
# ### Task 2: Data Type Conversion Quiz
#
# Create a short quiz that asks the user three questions, requiring answers in different data types `(string, integer, float)`. Convert the responses to the correct types and display them back to the user.

# %%
# Enter your code here

# %% [markdown]
# ### Task 3: Exception Handling
#
# Write a program that asks the user to input a number. Use `try` and `except` blocks to catch cases where the user inputs something that cannot be converted to a number. If an exception occurs, print an error message.

# %%
# Enter your code here

# %% [markdown]
# [Access the next lesson here - 002 Beginning Python](https://colab.research.google.com/drive/17FFw-uYjW-ZtQaCJx4ISKDif8i6HAcKh?usp=sharing)
