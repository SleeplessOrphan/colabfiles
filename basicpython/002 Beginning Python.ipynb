# %% [markdown]
# # Functions and Variables in Google Colab
#
# ## Objective
#
# In this lesson, we'll explore functions and variables in Python, focusing on the def, global, and return keywords. This will be demonstrated in a Google Colab environment.
#
# ## Skills Covered
#
# - Defining functions in Python
#
# - Understanding global and local variables
#
# - Utilising the return statement in functions
#
# ## Prerequisites
#
# Before starting, ensure you:
#
# - Have basic knowledge of Python programming.
#
# - Are familiar with Google Colab or similar Python environments.
#
# - Have access to an internet connection.
#
# ## Materials Required
#
# You need a computer with internet access and a Google Colab account.
#
# ---

# %% [markdown]
# ## Lesson Steps
#
# ### Step 1: Creating a Function
#
# Functions in Python are defined using the def keyword. Let's create a simple function in Google Colab.
#
# Type the following code:
#
# ```python
#
# def greet(name):
#
#     return f"Hello, {name}!"
#
# ```
# Run the cell to define the function.

# %%
# Enter code here

# %% [markdown]
# ### Step 2: Understanding global and Local Variables
#
# Variables can be either local (inside a function) or global (outside any function). Let's see how they work.
#
# 1. Add a new cell in Colab.
#
# 2. Insert this code:
#
# ```python
#
# # Global variable
#
# number = 10
#
# def show_number():
#
#     # Local variable
#
#     number = 5
#
#     print("Inside function:", number)
#
# show_number()
#
# print("Outside function:", number)
#
# ```
#
# 3. Run the cell to observe the difference between local and global variables.

# %%
# Enter code here

# %% [markdown]
# ### Step 4: Recap and Questions
#
# We've learned how to define functions, differentiate between global and local variables, and use the return statement in Google Colab. Now, feel free to ask questions or discuss any challenges you faced.

# %% [markdown]
# ### Exercise 1: Custom Greeting Program
#
# Objective: Create a program that asks the user for their name and then prints a custom greeting.
#
# - Use input() to get the user's name.
#
# - Create a function using def that takes the name as a parameter and returns a greeting string.
#
# - Use print() to display the greeting.

# %%
# Enter code here

# %% [markdown]
# ### Exercise 2: Simple Calculator
#
# Objective: Make a calculator that adds, subtracts, multiplies, or divides two numbers entered by the user.
#
# - Use input() to receive two numbers and the desired operation (add, subtract, multiply, divide) from the user.
#
# - Convert the input strings to float or int as appropriate.
#
# - Implement a function for each operation.
#
# - Use try and except to handle any division by zero errors.

# %%
# Enter code here

# %% [markdown]
# ### Exercise 3: Age in Days Converter
#
# Objective: Write a program that converts a person's age in years to days.
#
# - Ask the user for their age in years using input() and convert it to an integer.
#
# - Create a function that takes the age in years and returns the age in days (approximate each year as 365 days).
#
# - Use print() to display the result.

# %%
# Enter code here

# %% [markdown]
# ### Exercise 4: Temperature Converter
#
# Objective: Develop a program to convert temperature from Celsius to Fahrenheit and vice versa.
#
# - The program should ask the user which conversion they want to perform.
#
# - Implement two functions: one to convert Celsius to Fahrenheit and another for the reverse.
#
# - Use global variables if needed to store conversion constants.
#
# - Use try and except to handle any non-numeric inputs.

# %%
# Enter code here

# %% [markdown]
# ### Exercise 5: Simple Interest Calculator
#
# Objective: Create a program that calculates simple interest given principal, rate of interest, and time.
#
# - Define a function using def that takes principal, rate, and time as parameters and returns the calculated interest.
#
# - Use input() to gather these values from the user, and convert them to appropriate numeric types (`float` or int).
#
# - Ensure to use try and except blocks to handle invalid inputs.
#
# - The function should use return to provide the calculated interest, which should then be printed out.
#
# These exercises provide a practical application of the Python concepts you are teaching, and they can be progressively complex to suit different learning levels.

# %%
# Enter code here

# %% [markdown]
# [Access the next lesson here - 003 Beginning Python](https://colab.research.google.com/drive/1NEm3QwXRTyKkWs0dgLlgPz5oYNMfS_el?usp=sharing)
